# %%
# %load_ext autoreload
# %autoreload 2

# %%
import psycopg2
import pandas as pd
# import configparser
import yaml

# %%
from sql_postgres import create_staging_sales, drop_staging_sales
from sql_postgres import create_invoices, drop_invoices
from sql_postgres import create_items, drop_items
from sql_postgres import create_product_categories, drop_product_categories
from sql_postgres import create_stores, drop_stores

# %%
engine = psycopg2.connect(
    database="postgres",
    user="postgres",
    password="aQAbBqIpcmwVNVtOUt8M",
    host="database-1.ch27epgtqyjq.us-west-2.rds.amazonaws.com",
    port="5432",
)

# %%
cur = engine.cursor()

# %% [markdown]
# # Explore a small amount of data

# %% [markdown]
# For a first guess table schema, use [csvkit](https://csvkit.readthedocs.io/en/latest/index.html)'s `csvstat` and `csvsql`.  For Iowa_Liquor_sales, use a 10000 row subset
#
# ````
# csvstat subset_of_data.csv
# ````
#
# CREATE_STAGING_SALES_INITIAL formed from csvsql

# %%
with open('data.yml', 'r') as stream:
    data_config = yaml.safe_load(stream)

# %%
# data_config = configparser.ConfigParser()
# data_config.read('data.cfg')
# Out:
# ['data.cfg']

# %%
sales_bucket = data_config["sales_raw"]['bucket']
sales_key = data_config["sales_raw"]["key"]
n_rows = 10000
subset_file = 'subset.csv'

# %%
cmd = f"""aws s3api select-object-content --bucket {sales_bucket} \
  --key {sales_key} \
  --expression "select * from s3object limit {n_rows}" \
  --expression-type 'SQL' \
  --input-serialization '{{"CSV": {{}}, "CompressionType": "NONE"}}' \
  --output-serialization '{{"CSV": {{}}}}' "{subset_file}"
"""

# %%
! $cmd

# %%
# !./venv/bin/csvstat $subset_file
# Out:
#   1. "Invoice/Item Number"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         9999
# 	Longest value:         16 characters
# 	Most common values:    S15295000128 (1x)
# 	                       S16288500003 (1x)
# 	                       S09399500011 (1x)
# 	                       S04545700011 (1x)
# 	                       S16464700042 (1x)
#
#   2. "Date"
#
# 	Type of data:          Date
# 	Contains null values:  False
# 	Unique values:         832
# 	Smallest value:        2012-01-03
# 	Largest value:         2018-04-11
# 	Most common values:    2015-10-19 (27x)
# 	                       2013-05-21 (26x)
# 	                       2018-04-10 (26x)
# 	                       2015-04-15 (26x)
# 	                       2014-11-05 (24x)
#
#   3. "Store Number"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         1259
# 	Smallest value:        2,106
# 	Largest value:         9,002
# 	Sum:                   34,875,073
# 	Mean:                  3,487.856
# 	Median:                3,650
# 	StDev:                 873.879
# 	Most common values:    2,633 (85x)
# 	                       2,190 (84x)
# 	                       2,614 (70x)
# 	                       4,829 (67x)
# 	                       2,512 (64x)
#
#   4. "Store Name"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1238
# 	Longest value:         36 characters
# 	Most common values:    Hy-Vee #3 / BDI / Des Moines (85x)
# 	                       Central City Liquor, Inc. (84x)
# 	                       Hy-Vee #3 Food and Drugstore (70x)
# 	                       Central City 2 (67x)
# 	                       Hy-Vee Wine and Spirits / Iowa City (64x)
#
#   5. "Address"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1240
# 	Longest value:         30 characters
# 	Most common values:    3221 SE 14TH ST (113x)
# 	                       1460 2ND AVE (84x)
# 	                       1823 E KIMBERLY RD (70x)
# 	                       1501 MICHIGAN AVE (67x)
# 	                       1720 WATERFRONT DR (64x)
#
#   6. "City"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         354
# 	Longest value:         17 characters
# 	Most common values:    DES MOINES (849x)
# 	                       CEDAR RAPIDS (691x)
# 	                       DAVENPORT (446x)
# 	                       WATERLOO (344x)
# 	                       COUNCIL BLUFFS (308x)
#
#   7. "Zip Code"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         374
# 	Longest value:         5 characters
# 	Most common values:    52402 (262x)
# 	                       50010 (245x)
# 	                       52240 (239x)
# 	                       50613 (185x)
# 	                       50314 (184x)
#
#   8. "Store Location"
#
# 	Type of data:          Text
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1086
# 	Longest value:         45 characters
# 	Most common values:    None (893x)
# 	                       POINT (-93.596754 41.554101) (85x)
# 	                       POINT (-93.619787 41.60566) (84x)
# 	                       POINT (-90.548919 41.55678100000001) (70x)
# 	                       POINT (-93.613739 41.60572) (67x)
#
#   9. "County Number"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         99
# 	Smallest value:        1
# 	Largest value:         99
# 	Sum:                   569,395
# 	Mean:                  57.014
# 	Median:                61
# 	StDev:                 27.332
# 	Most common values:    77 (1766x)
# 	                       57 (863x)
# 	                       82 (645x)
# 	                       7 (571x)
# 	                       52 (483x)
#
#  10. "County"
#
# 	Type of data:          Text
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         111
# 	Longest value:         13 characters
# 	Most common values:    Polk (1765x)
# 	                       Linn (863x)
# 	                       Scott (645x)
# 	                       Black Hawk (570x)
# 	                       Johnson (476x)
#
#  11. "Category"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         70
# 	Smallest value:        1,011,100
# 	Largest value:         1,701,100
# 	Sum:                   10,437,478,673
# 	Mean:                  1,043,956.659
# 	Median:                1,032,080
# 	StDev:                 48,492.265
# 	Most common values:    1,031,080 (1275x)
# 	                       1,012,100 (934x)
# 	                       1,011,200 (546x)
# 	                       1,062,310 (519x)
# 	                       1,031,200 (502x)
#
#  12. "Category Name"
#
# 	Type of data:          Text
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         84
# 	Longest value:         34 characters
# 	Most common values:    VODKA 80 PROOF (1275x)
# 	                       CANADIAN WHISKIES (931x)
# 	                       STRAIGHT BOURBON WHISKIES (544x)
# 	                       SPICED RUM (519x)
# 	                       VODKA FLAVORED (502x)
#
#  13. "Vendor Number"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         73
# 	Smallest value:        35
# 	Largest value:         978
# 	Sum:                   2,549,739
# 	Mean:                  254.999
# 	Median:                260
# 	StDev:                 142.97
# 	Most common values:    260 (1635x)
# 	                       434 (1095x)
# 	                       65 (1001x)
# 	                       370 (607x)
# 	                       115 (558x)
#
#  14. "Vendor Name"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         87
# 	Longest value:         36 characters
# 	Most common values:    Diageo Americas (1634x)
# 	                       Luxco-St Louis (1092x)
# 	                       Jim Beam Brands (1001x)
# 	                       Pernod Ricard USA/Austin Nichols (604x)
# 	                       Constellation Wine Company, Inc. (556x)
#
#  15. "Item Number"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         1577
# 	Smallest value:        220
# 	Largest value:         988,536
# 	Sum:                   452,734,760
# 	Mean:                  45,278.004
# 	Median:                38,176
# 	StDev:                 46,634.483
# 	Most common values:    11,788 (114x)
# 	                       36,308 (89x)
# 	                       35,918 (69x)
# 	                       11,776 (68x)
# 	                       25,608 (59x)
#
#  16. "Item Description"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         1180
# 	Longest value:         56 characters
# 	Most common values:    Black Velvet (283x)
# 	                       Hawkeye Vodka (235x)
# 	                       Five O'clock Vodka (162x)
# 	                       Smirnoff Vodka 80 Prf (141x)
# 	                       Seagrams 7 Crown Bl Whiskey (136x)
#
#  17. "Pack"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         11
# 	Smallest value:        1
# 	Largest value:         48
# 	Sum:                   122,744
# 	Mean:                  12.276
# 	Median:                12
# 	StDev:                 7.324
# 	Most common values:    12 (6083x)
# 	                       6 (2614x)
# 	                       24 (887x)
# 	                       48 (233x)
# 	                       10 (104x)
#
#  18. "Bottle Volume (ml)"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         18
# 	Smallest value:        100
# 	Largest value:         4,800
# 	Sum:                   9,238,552
# 	Mean:                  923.948
# 	Median:                750
# 	StDev:                 474.399
# 	Most common values:    750 (4600x)
# 	                       1,750 (1985x)
# 	                       1,000 (1475x)
# 	                       375 (982x)
# 	                       500 (410x)
#
#  19. "State Bottle Cost"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         1009
# 	Smallest value:        0
# 	Largest value:         89.95
# 	Sum:                   93,266.28
# 	Mean:                  9.328
# 	Median:                7.84
# 	StDev:                 5.997
# 	Most common values:    8.25 (153x)
# 	                       10 (142x)
# 	                       6.5 (133x)
# 	                       6.3 (101x)
# 	                       12.5 (100x)
#
#  20. "State Bottle Retail"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         1190
# 	Smallest value:        0
# 	Largest value:         134.93
# 	Sum:                   140,198.64
# 	Mean:                  14.021
# 	Median:                11.79
# 	StDev:                 8.996
# 	Most common values:    15 (111x)
# 	                       9.74 (110x)
# 	                       15.74 (97x)
# 	                       12.38 (92x)
# 	                       9.45 (86x)
#
#  21. "Bottles Sold"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         55
# 	Smallest value:        1
# 	Largest value:         660
# 	Sum:                   100,877
# 	Mean:                  10.089
# 	Median:                6
# 	StDev:                 24.851
# 	Most common values:    12 (2727x)
# 	                       6 (1862x)
# 	                       2 (1360x)
# 	                       1 (1158x)
# 	                       3 (1089x)
#
#  22. "Sale (Dollars)"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         3142
# 	Smallest value:        0
# 	Largest value:         19,233
# 	Sum:                   1,319,360.2
# 	Mean:                  131.949
# 	Median:                67.5
# 	StDev:                 453.14
# 	Most common values:    62.28 (57x)
# 	                       73.8 (54x)
# 	                       180 (48x)
# 	                       60.72 (47x)
# 	                       64.56 (46x)
#
#  23. "Volume Sold (Liters)"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         110
# 	Smallest value:        0.2
# 	Largest value:         1,050
# 	Sum:                   94,491.64
# 	Mean:                  9.45
# 	Median:                5.25
# 	StDev:                 33.11
# 	Most common values:    9 (1919x)
# 	                       10.5 (1265x)
# 	                       1.5 (908x)
# 	                       2.25 (773x)
# 	                       12 (681x)
#
#  24. "Volume Sold (Gallons)"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         111
# 	Smallest value:        0.05
# 	Largest value:         277.38
# 	Sum:                   24,963.94
# 	Mean:                  2.497
# 	Median:                1.39
# 	StDev:                 8.747
# 	Most common values:    2.38 (1919x)
# 	                       2.77 (1265x)
# 	                       0.4 (908x)
# 	                       0.59 (773x)
# 	                       3.17 (681x)
#
# Row count: 9999

# %%
# !./venv/bin/csvsql $subset_file
# Out:
# CREATE TABLE subset (
# 	"Invoice/Item Number" VARCHAR NOT NULL,
# 	"Date" DATE NOT NULL,
# 	"Store Number" DECIMAL NOT NULL,
# 	"Store Name" VARCHAR NOT NULL,
# 	"Address" VARCHAR NOT NULL,
# 	"City" VARCHAR NOT NULL,
# 	"Zip Code" VARCHAR NOT NULL,
# 	"Store Location" VARCHAR,
# 	"County Number" DECIMAL,
# 	"County" VARCHAR,
# 	"Category" DECIMAL,
# 	"Category Name" VARCHAR,
# 	"Vendor Number" DECIMAL NOT NULL,
# 	"Vendor Name" VARCHAR NOT NULL,
# 	"Item Number" DECIMAL NOT NULL,
# 	"Item Description" VARCHAR NOT NULL,
# 	"Pack" DECIMAL NOT NULL,
# 	"Bottle Volume (ml)" DECIMAL NOT NULL,
# 	"State Bottle Cost" DECIMAL NOT NULL,
# 	"State Bottle Retail" DECIMAL NOT NULL,
# 	"Bottles Sold" DECIMAL NOT NULL,
# 	"Sale (Dollars)" DECIMAL NOT NULL,
# 	"Volume Sold (Liters)" DECIMAL NOT NULL,
# 	"Volume Sold (Gallons)" DECIMAL NOT NULL
# );

# %%
df_temp = pd.read_csv(subset_file, nrows=5)
df_temp
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S15295000128  10/23/2013          2524
# 1        S16288500003  12/16/2013          3740
# 2        S09399500011  12/11/2012          4495
# 3        S04545700011  03/14/2012          3525
# 4        S16464700042  12/23/2013          2638
#
#                              Store Name                    Address  \
# 0           Hy-Vee Food Store / Dubuque              3500 DODGE ST
# 1             Hometown Foods / Waterloo        1010 E MITCHELL AVE
# 2  Casey's General Store #3055 / Grundy                 504, G AVE
# 3                     Wines and Spirits               106 W 2ND ST
# 4  Hy-Vee Wine and Spirits / Cedar Fall  5925 UNIVERSITY AVE STE A
#
#             City  Zip Code                Store Location  County Number  \
# 0        DUBUQUE     52001                           NaN             31
# 1       WATERLOO     50702  POINT (-92.343118 42.476639)              7
# 2  GRUNDY CENTER     50638  POINT (-92.770411 42.361494)             38
# 3     WASHINGTON     52353  POINT (-91.692214 41.300399)             92
# 4    CEDAR FALLS     50613  POINT (-92.429331 42.512766)              7
#
#        County  ...  Item Number      Item Description  Pack  \
# 0     Dubuque  ...        40351  Burnett's Blackberry    12
# 1  Black Hawk  ...        64716           Ciroc Peach    12
# 2      Grundy  ...        37934            Skol Vodka    24
# 3  Washington  ...        13388        Northern Light     6
# 4  Black Hawk  ...        64601  Caravella Limoncello     6
#
#   Bottle Volume (ml)  State Bottle Cost State Bottle Retail  Bottles Sold  \
# 0                750               4.17                6.59             4
# 1                750              18.75               28.12            24
# 2                375               1.74                2.60             8
# 3               1750               8.32               12.48             6
# 4                750              11.25               16.87             6
#
#    Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)
# 0           26.36                   3.0                   0.79
# 1          674.88                  18.0                   4.76
# 2           20.80                   3.0                   0.79
# 3           74.88                  10.5                   2.77
# 4          101.22                   4.5                   1.19
#
# [5 rows x 24 columns]

# %% [markdown]
# From this we see that (summarizing only columns that may be of interest in this analysis):
#
# * the invoice/item number is unique and constant length (16 character)
# * date range is 2012-01 to 2018-04 and does not contain nulls
# * store number is a 4 digit ID and does not contain nulls
# * zip code is well formed (always 5 digits) and does not contain nulls
# * item number is numeric id up to 6 digits and does not contain nulls
# * item description is text up to at least 56 characters and has fewer unique values than item number, suggesting either the schema has changed over time or some different items use the same description
# * Category is a numeric ID of 9 digits and contains nulls
# * Catagory Name is text of maximum 34 characters (in the subset), contains nulls, and does not have the same number of unique values as category.  This suggests pairings of category names and categories may have changed over time or that some are missing
# * vendor numbers are 3 digit numeric IDs and contain nulls
# * vendor names contain nulls and the number of unique names does not match unique vendor numbers, suggesting missing items or a change in names over time
# * state bottle cost, retail, and sale are all numeric dollar values and contain nulls.  They will be staged as text to avoid rounding and allow their final destination to choose precision

# %% [markdown]
# From this, we define a staging table (which takes a direct import of all data in a batch CSV) with schema:

# %%
print(CREATE_STAGING_SALES)
# Out:
# CREATE TABLE staging_sales (
#   invoice_id VARCHAR NOT NULL,
#   date DATE NOT NULL,
#   store_number "Store Number" DECIMAL NOT NULL,
#   store_name VARCHAR NOT NULL,
#   address VARCHAR NOT NULL,
#   city VARCHAR NOT NULL,
#   zip VARCHAR NOT NULL,
#   store_location VARCHAR,
#   county_number DECIMAL,
#   county VARCHAR,
#   category DECIMAL,
#   category_name VARCHAR,
#   vendor_number DECIMAL NOT NULL,
#   vendor_name VARCHAR NOT NULL,
#   item_number DECIMAL NOT NULL,
#   item_description VARCHAR NOT NULL,
#   pack DECIMAL NOT NULL,
#   bottle_volume_ml DECIMAL NOT NULL,
#   state_bottle_cost DECIMAL NOT NULL,
#   state_bottle_retail DECIMAL NOT NULL,
#   bottles_sold DECIMAL NOT NULL,
#   sale_dollars DECIMAL NOT NULL,
#   volume_sold_liters DECIMAL NOT NULL,
#   volume_sold_gallons DECIMAL NOT NULL
# );

# %% [markdown]
# And we then define the following OLTP schema for the data we care about.  Note that we only include columns necessary for our current analysis goals - as we will keep the raw data files, additional columns could be loaded later

# %% [markdown]
# ( ADD SCHEMA HERE )

# %%
print(f"{CREATE_STAGING_SALES}\n")
print(f"{CREATE_INVOICES}\n")
print(f"{CREATE_ITEMS}\n")
print(f"{CREATE_PRODUCT_CATEGORIES}\n")
print(f"{CREATE_STORES}\n")
# Out:
# CREATE TABLE staging_sales (
#   invoice_id VARCHAR NOT NULL,
#   date DATE NOT NULL,
#   store_id DECIMAL NOT NULL,
#   store_name VARCHAR NOT NULL,
#   address VARCHAR NOT NULL,
#   city VARCHAR NOT NULL,
#   zip VARCHAR NOT NULL,
#   store_location VARCHAR,
#   county_number DECIMAL,
#   county VARCHAR,
#   category_id DECIMAL,
#   category_name VARCHAR,
#   vendor_id DECIMAL NOT NULL,
#   vendor_name VARCHAR NOT NULL,
#   item_id DECIMAL NOT NULL,
#   item_description VARCHAR NOT NULL,
#   pack DECIMAL NOT NULL,
#   bottle_volume_ml DECIMAL NOT NULL,
#   bottle_cost DECIMAL NOT NULL,
#   bottle_retail DECIMAL NOT NULL,
#   bottles_sold DECIMAL NOT NULL,
#   total_sale DECIMAL NOT NULL,
#   volume_sold_liters DECIMAL NOT NULL,
#   volume_sold_gallons DECIMAL NOT NULL
# );
#
#
#
# CREATE TABLE invoices (
#   invoice_id VARCHAR(16) NOT NULL,
#   store_id VARCHAR(4) NOT NULL,
#   date DATE NOT NULL,
#   bottle_cost DECIMAL(7,3) NOT NULL,
#   bottle_retail DECIMAL(7,3) NOT NULL,
#   bottles_sold SMALLINT NOT NULL,
#   total_sale DECIMAL(8,3) NOT NULL,
#   PRIMARY KEY (invoice_id),
#   FOREIGN KEY (store_id) REFERENCES stores,
# );
#
#
#
# CREATE TABLE items (
#   item_id VARCHAR(6) NOT NULL,
#   item_description VARCHAR(70) NOT NULL,
#   category_id VARCHAR(7),
#   vendor_id VARCHAR(3) NOT NULL,
#   PRIMARY KEY (item_id),
#   FOREIGN KEY (category_id) REFERENCES product_categories
# );
#
#
#
# CREATE TABLE product_categories (
#   category_id VARCHAR(7) NOT NULL,
#   category_name VARCHAR(50),
#   PRIMARY KEY (category_id)
# );
#
#
#
# CREATE TABLE stores (
#   store_id VARCHAR(4) NOT NULL,
#   store_name VARCHAR(50) NOT NULL,
#   zip VARCHAR(5) NOT NULL,
#   store_location VARCHAR,
#   PRIMARY KEY (store_id)
# );

# %% [markdown]
# # Explore a small amount of weather data

# %% [markdown]
# For a first guess table schema, use [csvkit](https://csvkit.readthedocs.io/en/latest/index.html)'s `csvstat` and `csvsql`
#
# ````
# csvstat subset_of_data.csv
# ````

# %%
bucket = data_config["weather_raw"]['bucket']
key = data_config["weather_raw"]["key"][0]
n_rows = 10000
subset_file = 'subset.csv'

# %%
cmd = f"""aws s3api select-object-content --bucket {bucket} \
  --key {key} \
  --expression "select * from s3object limit {n_rows}" \
  --expression-type 'SQL' \
  --input-serialization '{{"CSV": {{}}, "CompressionType": "NONE"}}' \
  --output-serialization '{{"CSV": {{}}}}' "{subset_file}"
"""

# %%
! $cmd

# %% [markdown]
# # TODO: EXPLAIN CHOICES ON QUERIES.  SHOW QUERIES.  THERES TEXT FILES OF IT ALL

# %%
# !./venv/bin/csvstat $subset_file
# Out:
#   1. "STATION"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         38
# 	Longest value:         11 characters
# 	Most common values:    USC00134561 (366x)
# 	                       USC00138806 (366x)
# 	                       USC00133239 (366x)
# 	                       USC00137844 (366x)
# 	                       USW00094991 (366x)
#
#   2. "NAME"
#
# 	Type of data:          Text
# 	Contains null values:  False
# 	Unique values:         38
# 	Longest value:         37 characters
# 	Most common values:    LAKE PARK, IA US (366x)
# 	                       WEBSTER CITY, IA US (366x)
# 	                       GILMAN, IA US (366x)
# 	                       SPENCER 1 N, IA US (366x)
# 	                       LAMONI MUNICIPAL AIRPORT, IA US (366x)
#
#   3. "LATITUDE"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         38
# 	Smallest value:        40.622
# 	Largest value:         43.448
# 	Sum:                   421,736.276
# 	Mean:                  42.178
# 	Median:                42.14
# 	StDev:                 0.706
# 	Most common values:    43.448 (366x)
# 	                       42.468 (366x)
# 	                       41.878 (366x)
# 	                       43.165 (366x)
# 	                       40.631 (366x)
#
#   4. "LONGITUDE"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         38
# 	Smallest value:        -96.406
# 	Largest value:         -90.646
# 	Sum:                   -934,544.947
# 	Mean:                  -93.464
# 	Median:                -93.65
# 	StDev:                 1.358
# 	Most common values:    -95.325 (366x)
# 	                       -93.797 (366x)
# 	                       -92.779 (366x)
# 	                       -95.147 (366x)
# 	                       -93.901 (366x)
#
#   5. "ELEVATION"
#
# 	Type of data:          Number
# 	Contains null values:  False
# 	Unique values:         37
# 	Smallest value:        161.5
# 	Largest value:         446.5
# 	Sum:                   3,183,161.3
# 	Mean:                  318.348
# 	Median:                312.4
# 	StDev:                 66.645
# 	Most common values:    345.9 (410x)
# 	                       446.5 (366x)
# 	                       326.7 (366x)
# 	                       312.4 (366x)
# 	                       404.2 (366x)
#
#   6. "DATE"
#
# 	Type of data:          Date
# 	Contains null values:  False
# 	Unique values:         366
# 	Smallest value:        2012-01-01
# 	Largest value:         2012-12-31
# 	Most common values:    2012-09-05 (34x)
# 	                       2012-09-13 (34x)
# 	                       2012-10-14 (34x)
# 	                       2012-04-15 (34x)
# 	                       2012-08-13 (33x)
#
#   7. "DAPR"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         9
# 	Smallest value:        2
# 	Largest value:         16
# 	Sum:                   93
# 	Mean:                  5.167
# 	Median:                4.5
# 	StDev:                 3.73
# 	Most common values:    None (9981x)
# 	                       2 (7x)
# 	                       4 (2x)
# 	                       6 (2x)
# 	                       7 (2x)
#
#   8. "MDPR"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         16
# 	Smallest value:        0
# 	Largest value:         1.25
# 	Sum:                   7.11
# 	Mean:                  0.395
# 	Median:                0.17
# 	StDev:                 0.441
# 	Most common values:    None (9981x)
# 	                       0 (3x)
# 	                       0.17 (2x)
# 	                       0.05 (1x)
# 	                       1.18 (1x)
#
#   9. "PRCP"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         188
# 	Smallest value:        0
# 	Largest value:         7.9
# 	Sum:                   814
# 	Mean:                  0.082
# 	Median:                0
# 	StDev:                 0.258
# 	Most common values:    0 (7380x)
# 	                       0.01 (186x)
# 	                       0.02 (170x)
# 	                       0.05 (127x)
# 	                       0.03 (126x)
#
#  10. "PSUN"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  11. "SNOW"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         63
# 	Smallest value:        0
# 	Largest value:         14
# 	Sum:                   643.8
# 	Mean:                  0.125
# 	Median:                0
# 	StDev:                 0.763
# 	Most common values:    None (4847x)
# 	                       0 (4844x)
# 	                       1 (42x)
# 	                       2 (25x)
# 	                       0.5 (23x)
#
#  12. "SNWD"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         32
# 	Smallest value:        0
# 	Largest value:         14
# 	Sum:                   2,424.3
# 	Mean:                  0.661
# 	Median:                0
# 	StDev:                 1.848
# 	Most common values:    None (6329x)
# 	                       0 (3032x)
# 	                       1 (126x)
# 	                       2 (122x)
# 	                       3 (85x)
#
#  13. "TAVG"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  14. "TMAX"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         102
# 	Smallest value:        3
# 	Largest value:         105
# 	Sum:                   328,596
# 	Mean:                  63.216
# 	Median:                66
# 	StDev:                 21.79
# 	Most common values:    None (4801x)
# 	                       76 (114x)
# 	                       83 (110x)
# 	                       82 (108x)
# 	                       79 (107x)
#
#  15. "TMIN"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         100
# 	Smallest value:        -21
# 	Largest value:         88
# 	Sum:                   208,328
# 	Mean:                  40.04
# 	Median:                41
# 	StDev:                 19.325
# 	Most common values:    None (4796x)
# 	                       47 (111x)
# 	                       31 (106x)
# 	                       24 (104x)
# 	                       60 (99x)
#
#  16. "TOBS"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         101
# 	Smallest value:        -15
# 	Largest value:         90
# 	Sum:                   170,298
# 	Mean:                  45.413
# 	Median:                47
# 	StDev:                 19.386
# 	Most common values:    None (6249x)
# 	                       31 (78x)
# 	                       64 (75x)
# 	                       58 (73x)
# 	                       28 (72x)
#
#  17. "TSUN"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  18. "WESD"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         12
# 	Smallest value:        0
# 	Largest value:         6
# 	Sum:                   23.8
# 	Mean:                  0.06
# 	Median:                0
# 	StDev:                 0.47
# 	Most common values:    None (9599x)
# 	                       0 (377x)
# 	                       0.1 (8x)
# 	                       0.3 (4x)
# 	                       6 (2x)
#
#  19. "WESF"
#
# 	Type of data:          Number
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         11
# 	Smallest value:        0
# 	Largest value:         2.3
# 	Sum:                   9.1
# 	Mean:                  0.147
# 	Median:                0
# 	StDev:                 0.348
# 	Most common values:    None (9937x)
# 	                       0 (39x)
# 	                       0.1 (8x)
# 	                       0.3 (4x)
# 	                       0.2 (3x)
#
#  20. "WT01"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         2
# 	Most common values:    None (9566x)
# 	                       True (433x)
#
#  21. "WT02"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         2
# 	Most common values:    None (9958x)
# 	                       True (41x)
#
#  22. "WT03"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         2
# 	Most common values:    None (9874x)
# 	                       True (125x)
#
#  23. "WT04"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  24. "WT05"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         2
# 	Most common values:    None (9997x)
# 	                       True (2x)
#
#  25. "WT06"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         2
# 	Most common values:    None (9997x)
# 	                       True (2x)
#
#  26. "WT07"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  27. "WT08"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         2
# 	Most common values:    None (9866x)
# 	                       True (133x)
#
#  28. "WT09"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  29. "WT10"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  30. "WT11"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         2
# 	Most common values:    None (9998x)
# 	                       True (1x)
#
#  31. "WT13"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  32. "WT14"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  33. "WT15"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  34. "WT16"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  35. "WT17"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  36. "WT18"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  37. "WT19"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  38. "WT21"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
#  39. "WT22"
#
# 	Type of data:          Boolean
# 	Contains null values:  True (excluded from calculations)
# 	Unique values:         1
# 	Most common values:    None (9999x)
#
# Row count: 9999

# %%
# !./venv/bin/csvsql $subset_file
# Out:
# CREATE TABLE subset (
# 	"STATION" VARCHAR NOT NULL,
# 	"NAME" VARCHAR NOT NULL,
# 	"LATITUDE" DECIMAL NOT NULL,
# 	"LONGITUDE" DECIMAL NOT NULL,
# 	"ELEVATION" DECIMAL NOT NULL,
# 	"DATE" DATE NOT NULL,
# 	"DAPR" DECIMAL,
# 	"MDPR" DECIMAL,
# 	"PRCP" DECIMAL,
# 	"PSUN" BOOLEAN,
# 	"SNOW" DECIMAL,
# 	"SNWD" DECIMAL,
# 	"TAVG" BOOLEAN,
# 	"TMAX" DECIMAL,
# 	"TMIN" DECIMAL,
# 	"TOBS" DECIMAL,
# 	"TSUN" BOOLEAN,
# 	"WESD" DECIMAL,
# 	"WESF" DECIMAL,
# 	"WT01" BOOLEAN,
# 	"WT02" BOOLEAN,
# 	"WT03" BOOLEAN,
# 	"WT04" BOOLEAN,
# 	"WT05" BOOLEAN,
# 	"WT06" BOOLEAN,
# 	"WT07" BOOLEAN,
# 	"WT08" BOOLEAN,
# 	"WT09" BOOLEAN,
# 	"WT10" BOOLEAN,
# 	"WT11" BOOLEAN,
# 	"WT13" BOOLEAN,
# 	"WT14" BOOLEAN,
# 	"WT15" BOOLEAN,
# 	"WT16" BOOLEAN,
# 	"WT17" BOOLEAN,
# 	"WT18" BOOLEAN,
# 	"WT19" BOOLEAN,
# 	"WT21" BOOLEAN,
# 	"WT22" BOOLEAN
# );

# %%
df_temp = pd.read_csv(subset_file, nrows=5)
df_temp
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S15295000128  10/23/2013          2524
# 1        S16288500003  12/16/2013          3740
# 2        S09399500011  12/11/2012          4495
# 3        S04545700011  03/14/2012          3525
# 4        S16464700042  12/23/2013          2638
#
#                              Store Name                    Address  \
# 0           Hy-Vee Food Store / Dubuque              3500 DODGE ST
# 1             Hometown Foods / Waterloo        1010 E MITCHELL AVE
# 2  Casey's General Store #3055 / Grundy                 504, G AVE
# 3                     Wines and Spirits               106 W 2ND ST
# 4  Hy-Vee Wine and Spirits / Cedar Fall  5925 UNIVERSITY AVE STE A
#
#             City  Zip Code                Store Location  County Number  \
# 0        DUBUQUE     52001                           NaN             31
# 1       WATERLOO     50702  POINT (-92.343118 42.476639)              7
# 2  GRUNDY CENTER     50638  POINT (-92.770411 42.361494)             38
# 3     WASHINGTON     52353  POINT (-91.692214 41.300399)             92
# 4    CEDAR FALLS     50613  POINT (-92.429331 42.512766)              7
#
#        County  ...  Item Number      Item Description  Pack  \
# 0     Dubuque  ...        40351  Burnett's Blackberry    12
# 1  Black Hawk  ...        64716           Ciroc Peach    12
# 2      Grundy  ...        37934            Skol Vodka    24
# 3  Washington  ...        13388        Northern Light     6
# 4  Black Hawk  ...        64601  Caravella Limoncello     6
#
#   Bottle Volume (ml)  State Bottle Cost State Bottle Retail  Bottles Sold  \
# 0                750               4.17                6.59             4
# 1                750              18.75               28.12            24
# 2                375               1.74                2.60             8
# 3               1750               8.32               12.48             6
# 4                750              11.25               16.87             6
#
#    Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)
# 0           26.36                   3.0                   0.79
# 1          674.88                  18.0                   4.76
# 2           20.80                   3.0                   0.79
# 3           74.88                  10.5                   2.77
# 4          101.22                   4.5                   1.19
#
# [5 rows x 24 columns]

# %% [markdown]
# From this we see that (summarizing only columns that may be of interest in this analysis):
#
# * the invoice/item number is unique and constant length (16 character)
# * date range is 2012-01 to 2018-04 and does not contain nulls
# * store number is a 4 digit ID and does not contain nulls
# * zip code is well formed (always 5 digits) and does not contain nulls
# * item number is numeric id up to 6 digits and does not contain nulls
# * item description is text up to at least 56 characters and has fewer unique values than item number, suggesting either the schema has changed over time or some different items use the same description
# * Category is a numeric ID of 9 digits and contains nulls
# * Catagory Name is text of maximum 34 characters (in the subset), contains nulls, and does not have the same number of unique values as category.  This suggests pairings of category names and categories may have changed over time or that some are missing
# * vendor numbers are 3 digit numeric IDs and contain nulls
# * vendor names contain nulls and the number of unique names does not match unique vendor numbers, suggesting missing items or a change in names over time
# * state bottle cost, retail, and sale are all numeric dollar values and contain nulls.  They will be staged as text to avoid rounding and allow their final destination to choose precision

# %% [markdown]
# From this, we define a staging table (which takes a direct import of all data in a batch CSV) with schema:

# %%
print(CREATE_STAGING_SALES)
# Out:
# CREATE TABLE staging_sales (
#   invoice_id VARCHAR NOT NULL,
#   date DATE NOT NULL,
#   store_number "Store Number" DECIMAL NOT NULL,
#   store_name VARCHAR NOT NULL,
#   address VARCHAR NOT NULL,
#   city VARCHAR NOT NULL,
#   zip VARCHAR NOT NULL,
#   store_location VARCHAR,
#   county_number DECIMAL,
#   county VARCHAR,
#   category DECIMAL,
#   category_name VARCHAR,
#   vendor_number DECIMAL NOT NULL,
#   vendor_name VARCHAR NOT NULL,
#   item_number DECIMAL NOT NULL,
#   item_description VARCHAR NOT NULL,
#   pack DECIMAL NOT NULL,
#   bottle_volume_ml DECIMAL NOT NULL,
#   state_bottle_cost DECIMAL NOT NULL,
#   state_bottle_retail DECIMAL NOT NULL,
#   bottles_sold DECIMAL NOT NULL,
#   sale_dollars DECIMAL NOT NULL,
#   volume_sold_liters DECIMAL NOT NULL,
#   volume_sold_gallons DECIMAL NOT NULL
# );

# %% [markdown]
# And we then define the following OLTP schema for the data we care about.  Note that we only include columns necessary for our current analysis goals - as we will keep the raw data files, additional columns could be loaded later

# %% [markdown]
# ( ADD SCHEMA HERE )

# %%
print(f"{CREATE_STAGING_SALES}\n")
print(f"{CREATE_INVOICES}\n")
print(f"{CREATE_ITEMS}\n")
print(f"{CREATE_PRODUCT_CATEGORIES}\n")
print(f"{CREATE_STORES}\n")
# Out:
# CREATE TABLE staging_sales (
#   invoice_id VARCHAR NOT NULL,
#   date DATE NOT NULL,
#   store_id DECIMAL NOT NULL,
#   store_name VARCHAR NOT NULL,
#   address VARCHAR NOT NULL,
#   city VARCHAR NOT NULL,
#   zip VARCHAR NOT NULL,
#   store_location VARCHAR,
#   county_number DECIMAL,
#   county VARCHAR,
#   category_id DECIMAL,
#   category_name VARCHAR,
#   vendor_id DECIMAL NOT NULL,
#   vendor_name VARCHAR NOT NULL,
#   item_id DECIMAL NOT NULL,
#   item_description VARCHAR NOT NULL,
#   pack DECIMAL NOT NULL,
#   bottle_volume_ml DECIMAL NOT NULL,
#   bottle_cost DECIMAL NOT NULL,
#   bottle_retail DECIMAL NOT NULL,
#   bottles_sold DECIMAL NOT NULL,
#   total_sale DECIMAL NOT NULL,
#   volume_sold_liters DECIMAL NOT NULL,
#   volume_sold_gallons DECIMAL NOT NULL
# );
#
#
#
# CREATE TABLE invoices (
#   invoice_id VARCHAR(16) NOT NULL,
#   store_id VARCHAR(4) NOT NULL,
#   date DATE NOT NULL,
#   bottle_cost DECIMAL(7,3) NOT NULL,
#   bottle_retail DECIMAL(7,3) NOT NULL,
#   bottles_sold SMALLINT NOT NULL,
#   total_sale DECIMAL(8,3) NOT NULL,
#   PRIMARY KEY (invoice_id),
#   FOREIGN KEY (store_id) REFERENCES stores,
# );
#
#
#
# CREATE TABLE items (
#   item_id VARCHAR(6) NOT NULL,
#   item_description VARCHAR(70) NOT NULL,
#   category_id VARCHAR(7),
#   vendor_id VARCHAR(3) NOT NULL,
#   PRIMARY KEY (item_id),
#   FOREIGN KEY (category_id) REFERENCES product_categories
# );
#
#
#
# CREATE TABLE product_categories (
#   category_id VARCHAR(7) NOT NULL,
#   category_name VARCHAR(50),
#   PRIMARY KEY (category_id)
# );
#
#
#
# CREATE TABLE stores (
#   store_id VARCHAR(4) NOT NULL,
#   store_name VARCHAR(50) NOT NULL,
#   zip VARCHAR(5) NOT NULL,
#   store_location VARCHAR,
#   PRIMARY KEY (store_id)
# );

# %% [markdown]
# # Assumptions/statements
#
# * We will keep all raw data files as a backup.  This allows us to ingest into our DBs only the data we currently plan to use - if additional data was needed in future we could load that as well
# * Product/category definitions used in analysis will take the most recent definition as truth.  For example, if in 2012 item `12345` was classified as category `10`, but later item `12345` was classified as category `20`, we will use category `20` for all analyses.  This avoids having to maintain the lineage of any product/category data
# * Bottle cost and retail sale price will change over time and thus cannot be an attribute directly in the item table

# %% [markdown]
# # Outstanding questions
#
# * do we have weather data for all zips in sales?
# * do we have population data for all zips in sales?

# %% [markdown]
# # TODO for ETL
#
# * Load product data (item/category) chronologically so we keep only the most recent

# %%
from sql_postgres import get_station_latitude_longitude

# %%
cur = engine.cursor()
cur.execute(get_station_latitude_longitude)
records = cur.fetchall()

# %%
import geopy
geolocator = geopy.Nominatim(user_agent='etl')
zipcode = geolocator.reverse((41.5445, -90.591)).raw['address']['postcode']

# %%
def lat_long_to_zip_geo(latitude, longitude):
    location = geolocator.reverse((latitude, longitude))
    
    # Not all locations from this service have zip codes... if nothing, return None
    try:
        return location.raw['address']['postcode']
    except KeyError:
        return None
    
print(lat_long_to_zip(41.5445, -90.591))
print(lat_long_to_zip(43.4022489, -91.2864117))
# Out:
# 52804
# None

# %%
f = lambda t: (t[0], lat_long_to_zip(t[1], t[2]))
list(map(f, records[:3]))
# Out:
# 43.401739
# -91.28507
# 43.1409
# -91.4926
# 40.724725
# -92.868039
# [('US1IAAL0005',
#   Location(Allamakee County, Iowa, United States of America, (43.4022489, -91.2864117, 0.0))),
#  ('US1IAAL0006',
#   Location(672, Woodchuck Drive, Allamakee County, Iowa, 52162, United States of America, (43.14080759357605, -91.49254566651234, 0.0))),
#  ('US1IAAP0001',
#   Location(1024, South 18th Street, Centerville, Appanoose County, Iowa, 52544, United States of America, (40.7247251744186, -92.86801541860466, 0.0)))]

# %%
from uszipcode import SearchEngine
search = SearchEngine(simple_zipcode=True)
search.by_coordinates(43.4022489, -91.2864117, returns=1)[0].zipcode
# Out:
# Start downloading data for simple zipcode database, total size 9MB ...
#   1 MB finished ...
#   2 MB finished ...
#   3 MB finished ...
#   4 MB finished ...
#   5 MB finished ...
#   6 MB finished ...
#   7 MB finished ...
#   8 MB finished ...
#   9 MB finished ...
#   10 MB finished ...
#   Complete!

# %%
search.by_coordinates(43.4022489, -91.2864117, returns=1)[0].zipcode
# Out:
# '52151'

# %%
def lat_long_to_zip(latitude, longitude, search=None):
    latitude = float(latitude)
    longitude = float(longitude)
    if not search:
        search = SearchEngine(simple_zipcode=True)
    return search.by_coordinates(latitude, longitude, returns=1)[0].zipcode

# %%
search = SearchEngine(simple_zipcode=True)
f = lambda t: (t[0], lat_long_to_zip(t[1], t[2], search))
zipcode_records = map(f, records)

# %%
# Out:
# "('US1IAAL0005', '52151'), ('US1IAAL0006', '52156'), ('US1IAAP0001', '52544'), ('US1IAAP0004', '52544'), ('US1IAAP0007', '52544'), ('US1IAAP0008', '52593'), ('US1IAAP0009', '52544'), ('US1IAAP0010', '52581'), ('US1IAAP0011', '52571'), ('US1IABC0002', '52326'), ('US1IABC0005', '52352'), ('US1IABC0006', '50644'), ('US1IABC0008', '50644'), ('US1IABC0009', '50607'), ('US1IABH0003', '50613'), ('US1IABH0006', '50702'), ('US1IABH0007', '50613'), ('US1IABH0008', '50703'), ('US1IABH0010', '50613'), ('US1IABH0015', '50701'), ('US1IABH0017', '50667'), ('US1IABH0018', '50702'), ('US1IABH0019', '50702'), ('US1IABM0002', '50666'), ('US1IABN0003', '50212'), ('US1IABN0005', '50223'), ('US1IABN0009', '50156'), ('US1IABN0012', '50212'), ('US1IABN0013', '50276'), ('US1IABT0011', '52313'), ('US1IABT0012', '52206'), ('US1IABT0013', '52345'), ('US1IABU0002', '50633'), ('US1IABU0003', '50619'), ('US1IABV0001', '50588'), ('US1IABV0002', '51002'), ('US1IACD0005', '52747'), ('US1IACD0007', '52358'), ('US1IACF0002', '51461'), ('US1IACF0005', '51454'), ('US1IACF0006', '51439'), ('US1IACG0004', '50401'), ('US1IACG0005', '50467'), ('US1IACG0006', '50401'), ('US1IACG0007', '50477'), ('US1IACG0011', '50401'), ('US1IACH0002', '50563'), ('US1IACK0001', '51014'), ('US1IACK0002', '51012'), ('US1IACK0003', '51014'), ('US1IACK0005', '51012'), ('US1IACL0002', '50213'), ('US1IACL0003', '50174'), ('US1IACL0004', '50174'), ('US1IACN0001', '52742'), ('US1IACN0002', '52729'), ('US1IACN0005', '52730'), ('US1IACN0008', '52037'), ('US1IACN0010', '52730'), ('US1IACN0011', '52742'), ('US1IACN0012', '52254'), ('US1IACN0013', '52750'), ('US1IACN0017', '52731'), ('US1IACR0003', '51401'), ('US1IACR0005', '51463'), ('US1IACR0006', '51443'), ('US1IACR0007', '51455'), ('US1IACR0009', '51430'), ('US1IACS0002', '50020'), ('US1IACS0004', '50022'), ('US1IACS0005', '50042'), ('US1IACT0007', '52157'), ('US1IACW0001', '50659'), ('US1IACW0002', '50659'), ('US1IACW0003', '50659'), ('US1IACY0002', '51338'), ('US1IACY0004', '51301'), ('US1IADB0011', '52001'), ('US1IADB0012', '52068'), ('US1IADB0016', '52068'), ('US1IADB0018', '52002'), ('US1IADB0019', '52002'), ('US1IADB0020', '52002'), ('US1IADB0021', '52039'), ('US1IADK0003', '51347'), ('US1IADK0004', '51351'), ('US1IADK0006', '51347'), ('US1IADL0001', '50063'), ('US1IADL0004', '50063'), ('US1IADL0005', '50263'), ('US1IADL0014', '50146'), ('US1IADL0017', '50063'), ('US1IADL0018', '50263'), ('US1IADL0020', '50167'), ('US1IADL0022', '50323'), ('US1IADL0024', '50263'), ('US1IADL0026', '50063'), ('US1IADL0027', '50323'), ('US1IADL0031', '50063'), ('US1IADM0001', '52650'), ('US1IADM0004', '52655'), ('US1IADM0007', '52658'), ('US1IADM0008', '52601'), ('US1IADM0010', '52601'), ('US1IADV0001', '52560'), ('US1IADV0002', '52572'), ('US1IADV0003', '63548'), ('US1IADV0004', '52537'), ('US1IADV0005', '52584'), ('US1IADV0007', '52552'), ('US1IADV0008', '52584'), ('US1IADV0009', '52537'), ('US1IADV0010', '52560'), ('US1IADV0013', '52594'), ('US1IADV0014', '52552'), ('US1IADV0015', '52572'), ('US1IADV0016', '52584'), ('US1IADW0006', '52219'), ('US1IADW0009', '52057'), ('US1IAEM0001', '51365'), ('US1IAEM0003', '50578'), ('US1IAFL0003', '50458'), ('US1IAFM0001', '51652'), ('US1IAFR0001', '50452'), ('US1IAFY0002', '50662'), ('US1IAFY0003', '52171'), ('US1IAFY0004', '52171'), ('US1IAGN0001', '50050'), ('US1IAGN0004', '50050'), ('US1IAGT0001', '50277'), ('US1IAGT0003', '50026'), ('US1IAHB0002', '50529'), ('US1IAHD0005', '50672'), ('US1IAHM0001', '50595'), ('US1IAHN0002', '50423'), ('US1IAHN0004', '50438'), ('US1IAHR0002', '51579'), ('US1IAHR0003', '51550'), ('US1IAHR0004', '51563'), ('US1IAHR0006', '51579'), ('US1IAHR0007', '51557'), ('US1IAHR0010', '51555'), ('US1IAHR0011', '51555'), ('US1IAHR0013', '51546'), ('US1IAHR0014', '51523'), ('US1IAHR0016', '51546'), ('US1IAHY0001', '52645'), ('US1IAHY0004', '52645'), ('US1IAHY0005', '52649'), ('US1IAIA0001', '52316'), ('US1IAIA0002', '52301'), ('US1IAIA0006', '52203'), ('US1IAIA0013', '52361'), ('US1IAIA0018', '5230 ...

# %%
str(list(zipcode_records))
# Out:
# "[('US1IAAL0005', '52151'), ('US1IAAL0006', '52156'), ('US1IAAP0001', '52544'), ('US1IAAP0004', '52544'), ('US1IAAP0007', '52544'), ('US1IAAP0008', '52593'), ('US1IAAP0009', '52544'), ('US1IAAP0010', '52581'), ('US1IAAP0011', '52571'), ('US1IABC0002', '52326'), ('US1IABC0005', '52352'), ('US1IABC0006', '50644'), ('US1IABC0008', '50644'), ('US1IABC0009', '50607'), ('US1IABH0003', '50613'), ('US1IABH0006', '50702'), ('US1IABH0007', '50613'), ('US1IABH0008', '50703'), ('US1IABH0010', '50613'), ('US1IABH0015', '50701'), ('US1IABH0017', '50667'), ('US1IABH0018', '50702'), ('US1IABH0019', '50702'), ('US1IABM0002', '50666'), ('US1IABN0003', '50212'), ('US1IABN0005', '50223'), ('US1IABN0009', '50156'), ('US1IABN0012', '50212'), ('US1IABN0013', '50276'), ('US1IABT0011', '52313'), ('US1IABT0012', '52206'), ('US1IABT0013', '52345'), ('US1IABU0002', '50633'), ('US1IABU0003', '50619'), ('US1IABV0001', '50588'), ('US1IABV0002', '51002'), ('US1IACD0005', '52747'), ('US1IACD0007', '52358'), ('US1IACF0002', '51461'), ('US1IACF0005', '51454'), ('US1IACF0006', '51439'), ('US1IACG0004', '50401'), ('US1IACG0005', '50467'), ('US1IACG0006', '50401'), ('US1IACG0007', '50477'), ('US1IACG0011', '50401'), ('US1IACH0002', '50563'), ('US1IACK0001', '51014'), ('US1IACK0002', '51012'), ('US1IACK0003', '51014'), ('US1IACK0005', '51012'), ('US1IACL0002', '50213'), ('US1IACL0003', '50174'), ('US1IACL0004', '50174'), ('US1IACN0001', '52742'), ('US1IACN0002', '52729'), ('US1IACN0005', '52730'), ('US1IACN0008', '52037'), ('US1IACN0010', '52730'), ('US1IACN0011', '52742'), ('US1IACN0012', '52254'), ('US1IACN0013', '52750'), ('US1IACN0017', '52731'), ('US1IACR0003', '51401'), ('US1IACR0005', '51463'), ('US1IACR0006', '51443'), ('US1IACR0007', '51455'), ('US1IACR0009', '51430'), ('US1IACS0002', '50020'), ('US1IACS0004', '50022'), ('US1IACS0005', '50042'), ('US1IACT0007', '52157'), ('US1IACW0001', '50659'), ('US1IACW0002', '50659'), ('US1IACW0003', '50659'), ('US1IACY0002', '51338'), ('US1IACY0004', '51301'), ('US1IADB0011', '52001'), ('US1IADB0012', '52068'), ('US1IADB0016', '52068'), ('US1IADB0018', '52002'), ('US1IADB0019', '52002'), ('US1IADB0020', '52002'), ('US1IADB0021', '52039'), ('US1IADK0003', '51347'), ('US1IADK0004', '51351'), ('US1IADK0006', '51347'), ('US1IADL0001', '50063'), ('US1IADL0004', '50063'), ('US1IADL0005', '50263'), ('US1IADL0014', '50146'), ('US1IADL0017', '50063'), ('US1IADL0018', '50263'), ('US1IADL0020', '50167'), ('US1IADL0022', '50323'), ('US1IADL0024', '50263'), ('US1IADL0026', '50063'), ('US1IADL0027', '50323'), ('US1IADL0031', '50063'), ('US1IADM0001', '52650'), ('US1IADM0004', '52655'), ('US1IADM0007', '52658'), ('US1IADM0008', '52601'), ('US1IADM0010', '52601'), ('US1IADV0001', '52560'), ('US1IADV0002', '52572'), ('US1IADV0003', '63548'), ('US1IADV0004', '52537'), ('US1IADV0005', '52584'), ('US1IADV0007', '52552'), ('US1IADV0008', '52584'), ('US1IADV0009', '52537'), ('US1IADV0010', '52560'), ('US1IADV0013', '52594'), ('US1IADV0014', '52552'), ('US1IADV0015', '52572'), ('US1IADV0016', '52584'), ('US1IADW0006', '52219'), ('US1IADW0009', '52057'), ('US1IAEM0001', '51365'), ('US1IAEM0003', '50578'), ('US1IAFL0003', '50458'), ('US1IAFM0001', '51652'), ('US1IAFR0001', '50452'), ('US1IAFY0002', '50662'), ('US1IAFY0003', '52171'), ('US1IAFY0004', '52171'), ('US1IAGN0001', '50050'), ('US1IAGN0004', '50050'), ('US1IAGT0001', '50277'), ('US1IAGT0003', '50026'), ('US1IAHB0002', '50529'), ('US1IAHD0005', '50672'), ('US1IAHM0001', '50595'), ('US1IAHN0002', '50423'), ('US1IAHN0004', '50438'), ('US1IAHR0002', '51579'), ('US1IAHR0003', '51550'), ('US1IAHR0004', '51563'), ('US1IAHR0006', '51579'), ('US1IAHR0007', '51557'), ('US1IAHR0010', '51555'), ('US1IAHR0011', '51555'), ('US1IAHR0013', '51546'), ('US1IAHR0014', '51523'), ('US1IAHR0016', '51546'), ('US1IAHY0001', '52645'), ('US1IAHY0004', '52645'), ('US1IAHY0005', '52649'), ('US1IAIA0001', '52316'), ('US1IAIA0002', '52301'), ('US1IAIA0006', '52203'), ('US1IAIA0013', '52361'), ('US1IAIA0018', '523 ...

# %%
cur.execute(create_staging_sales)

# %% [raw]
# engine.commit()

# %%
query = "SELECT * FROM test_iowa_table LIMIT 5"

# %%
# # Deleting header which happened to be in table by mistake
# cur.execute("""
# DELETE FROM test_iowa_table 
# WHERE invoice_id in (
#     SELECT invoice_id FROM test_iowa_table LIMIT 1
#     )
# """)

# %%
cur.execute(query)
# for t in cur:
#     print(t)

# %%
pd.read_sql(query, engine, )
# Out:
#             invoice_id        date  store_number                 store_name  \
# 0  Invoice/Item Number        Date  Store Number                 Store Name
# 1         S09553800028  12/18/2012          3717   The Liquor Stop / Sumner
# 2         S14077800069  10/04/2013          2506  Hy-Vee #1044 / Burlington
# 3         S08306600029  10/15/2012          3766       Kolby's Liquor Store
# 4         S11151600002  03/18/2013          2612       Hy-Vee Store / Perry
#
#            address         city       zip  \
# 0          Address         City  Zip Code
# 1     201 W 1st ST       SUMNER     50674
# 2      3140 AGENCY   BURLINGTON     52601
# 3  419 W MILWAUKEE  NEW HAMPTON     50659
# 4     1215  141 ST        PERRY     50220
#
#                          store_location  county_number      county  ...  \
# 0                        Store Location  County Number      County  ...
# 1  POINT (-92.09922100000001 42.847479)             09      Bremer  ...
# 2          POINT (-91.136655 40.814666)             29  Des Moines  ...
# 3  POINT (-92.32302900000002 43.066752)             19   Chickasaw  ...
# 4          POINT (-94.104501 41.830292)             25      Dallas  ...
#
#    item_number              item_description  pack    bottle_volume_ml  \
# 0  Item Number              Item Description  Pack  Bottle Volume (ml)
# 1        36305                 Hawkeye Vodka    12                 750
# 2        64868     Fireball Cinnamon Whiskey     6                1750
# 3        73456  Dekuyper Luscious Razzmatazz    12                 750
# 4        11776                  Black Velvet    12                 750
#
#    state_bottle_cost  state_bottle_retail  bottles_sold    sale_dollars  \
# 0  State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)
# 1               3.25                 4.88             2            9.76
# 2              15.33                23.00            30          690.00
# 3               6.30                 9.45             2           18.90
# 4               5.23                 7.84            12           94.08
#
#      volume_sold_liters    volume_sold_gallons
# 0  Volume Sold (Liters)  Volume Sold (Gallons)
# 1                  1.50                   0.40
# 2                 52.50                  13.87
# 3                  1.50                   0.40
# 4                  9.00                   2.38
#
# [5 rows x 24 columns]

# %%
pd.DataFrame(cur.fetchall())
# Out:
#                     0           1             2                          3   \
# 0  Invoice/Item Number        Date  Store Number                 Store Name
# 1         S09553800028  12/18/2012          3717   The Liquor Stop / Sumner
# 2         S14077800069  10/04/2013          2506  Hy-Vee #1044 / Burlington
# 3         S08306600029  10/15/2012          3766       Kolby's Liquor Store
# 4         S11151600002  03/18/2013          2612       Hy-Vee Store / Perry
#
#                 4            5         6   \
# 0          Address         City  Zip Code
# 1     201 W 1st ST       SUMNER     50674
# 2      3140 AGENCY   BURLINGTON     52601
# 3  419 W MILWAUKEE  NEW HAMPTON     50659
# 4     1215  141 ST        PERRY     50220
#
#                                      7              8           9   ...  \
# 0                        Store Location  County Number      County  ...
# 1  POINT (-92.09922100000001 42.847479)             09      Bremer  ...
# 2          POINT (-91.136655 40.814666)             29  Des Moines  ...
# 3  POINT (-92.32302900000002 43.066752)             19   Chickasaw  ...
# 4          POINT (-94.104501 41.830292)             25      Dallas  ...
#
#             14                            15    16                  17  \
# 0  Item Number              Item Description  Pack  Bottle Volume (ml)
# 1        36305                 Hawkeye Vodka    12                 750
# 2        64868     Fireball Cinnamon Whiskey     6                1750
# 3        73456  Dekuyper Luscious Razzmatazz    12                 750
# 4        11776                  Black Velvet    12                 750
#
#                   18                   19            20              21  \
# 0  State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)
# 1               3.25                 4.88             2            9.76
# 2              15.33                23.00            30          690.00
# 3               6.30                 9.45             2           18.90
# 4               5.23                 7.84            12           94.08
#
#                      22                     23
# 0  Volume Sold (Liters)  Volume Sold (Gallons)
# 1                  1.50                   0.40
# 2                 52.50                  13.87
# 3                  1.50                   0.40
# 4                  9.00                   2.38
#
# [5 rows x 24 columns]

# %%
header = cur.fetchone().split(',')
example
# Out:
# ('S09553800028',
#  '12/18/2012',
#  '3717',
#  'The Liquor Stop / Sumner',
#  '201 W 1st ST',
#  'SUMNER',
#  '50674',
#  'POINT (-92.09922100000001 42.847479)',
#  '09',
#  'Bremer',
#  '1031080',
#  'VODKA 80 PROOF',
#  '434',
#  'Luxco-St Louis',
#  '36305',
#  'Hawkeye Vodka',
#  '12',
#  '750',
#  '3.25',
#  '4.88',
#  '2',
#  '9.76',
#  '1.50',
#  '0.40')
